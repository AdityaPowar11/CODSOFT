# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading Dataframe

# %%
import chardet

# Detect the file encoding
with open('movies.csv', 'rb') as file:
    raw_data = file.read()
    result = chardet.detect(raw_data)
    encoding = result['encoding']
    print(f"Detected encoding: {encoding}")

# Read the file content with the detected encoding
df = pd.read_csv('movies.csv', encoding=encoding)
# Out:
# Detected encoding: ISO-8859-1

# %%
df
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                             #Homecoming -2021.0   90 min   Drama, Musical
# 3                                 #Yaaram -2019.0  110 min  Comedy, Romance
# 4                       ...And Once Again -2010.0  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga -1988.0      NaN           Action
# 15505                               Zulmi -1999.0  129 min    Action, Drama
# 15506                           Zulmi Raj -2005.0      NaN           Action
# 15507                       Zulmi Shikari -1988.0      NaN           Action
# 15508                        Zulm-O-Sitam -1998.0  130 min    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15509 rows x 10 columns]

# %%
df.shape
# Out:
# (15509, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  15509 non-null  float64
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     15509 non-null  float64
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 1.2+ MB

# %% [markdown]
# Handling DataTypes

# %%
df['Year']= abs(df['Year'])

# %%
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

# %%
df['Votes'] =df['Votes'].str.replace(',','')

# %%
df['Votes'] = pd.to_numeric(df['Votes'], errors='coerce')

# %%
df.isna().sum()
# Out:
# Name           0
# Year         528
# Duration       0
# Genre       1877
# Rating         0
# Votes          0
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df['Duration'] = df['Duration'].str.replace(' min','')

# %%
df['Duration'] = pd.to_numeric(df['Duration'], errors='coerce')

# %%
df['Duration'].fillna(df['Duration'].median(), inplace=True)

# %%
df['Votes'] = df['Votes'].fillna(df['Votes'].median())

# %%
df['Rating'].fillna(df['Rating'].median(), inplace=True)

# %% [markdown]
# Handling Null Values

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df.shape
# Out:
# (11086, 10)

# %%
df.drop(columns=['Name', "Actor 3"],inplace=True)

# %%
df['Year'] = df['Year'].astype(int)
df['Duration'] = df['Duration'].astype(int)
df['Votes'] = df['Votes'].astype(int)
df['Rating'] = df['Rating'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11086 entries, 1 to 15508
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      11086 non-null  int64
#  1   Duration  11086 non-null  int64
#  2   Genre     11086 non-null  object
#  3   Rating    11086 non-null  float64
#  4   Votes     11086 non-null  int64
#  5   Director  11086 non-null  object
#  6   Actor 1   11086 non-null  object
#  7   Actor 2   11086 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 779.5+ KB

# %% [markdown]
# Splitting Genre colums using ordinal encoding

# %%
def split_genre_column(MovieData,Genre):

    MovieData['Genre1'] = MovieData[Genre].str.split(',', expand=True)[0]
    MovieData['Genre2'] = MovieData[Genre].str.split(',', expand=True)[1]
    MovieData['Genre3'] = MovieData[Genre].str.split(',', expand=True)[2]
    return MovieData

split_genre_column(df,'Genre')
# Out:
#        Year  Duration                   Genre  Rating  Votes  \
# 1      2019       109                   Drama     7.0      8
# 2      2021        90          Drama, Musical     6.0     55
# 3      2019       110         Comedy, Romance     4.4     35
# 4      2010       105                   Drama     6.0     55
# 5      1997       147  Comedy, Drama, Musical     4.7    827
# ...     ...       ...                     ...     ...    ...
# 15502  1979       131                  Action     6.0     55
# 15503  1989       125    Action, Crime, Drama     5.8     44
# 15504  1988       131                  Action     4.6     11
# 15505  1999       129           Action, Drama     4.5    655
# 15508  1998       130           Action, Drama     6.2     20
#
#                  Director           Actor 1                 Actor 2  Genre1  \
# 1           Gaurav Bakshi      Rasika Dugal          Vivek Ghamande   Drama
# 2      Soumyajit Majumdar      Sayani Gupta       Plabita Borthakur   Drama
# 3              Ovais Khan           Prateik              Ishita Raj  Comedy
# 4            Amol Palekar      Rajat Kapoor      Rituparna Sengupta   Drama
# 5            Rahul Rawail        Bobby Deol  Aishwarya Rai Bachchan  Comedy
# ...                   ...               ...                     ...     ...
# 15502     Dinesh-Ramanesh       Ramesh Puri              Jalal Agha  Action
# 15503     S.P. Muthuraman       Chiranjeevi              Jayamalini  Action
# 15504       Mahendra Shah  Naseeruddin Shah           Sumeet Saigal  Action
# 15505          Kuku Kohli      Akshay Kumar          Twinkle Khanna  Action
# 15508        K.C. Bokadia        Dharmendra              Jaya Prada  Action
#
#          Genre2    Genre3
# 1          None      None
# 2       Musical      None
# 3       Romance      None
# 4          None      None
# 5         Drama   Musical
# ...         ...       ...
# 15502      None      None
# 15503     Crime     Drama
# 15504      None      None
# 15505     Drama      None
# 15508     Drama      None
#
# [11086 rows x 11 columns]

# %%
df.isna().sum()
# Out:
# Year           0
# Duration       0
# Genre          0
# Rating         0
# Votes          0
# Director       0
# Actor 1        0
# Actor 2        0
# Genre1         0
# Genre2      5231
# Genre3      8000
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df.head()
# Out:
#    Year  Duration  Rating  Votes            Director       Actor 1  \
# 1  2019       109     7.0      8       Gaurav Bakshi  Rasika Dugal
# 2  2021        90     6.0     55  Soumyajit Majumdar  Sayani Gupta
# 3  2019       110     4.4     35          Ovais Khan       Prateik
# 4  2010       105     6.0     55        Amol Palekar  Rajat Kapoor
# 5  1997       147     4.7    827        Rahul Rawail    Bobby Deol
#
#                   Actor 2  Genre1  Genre2  Genre3
# 1          Vivek Ghamande       0       0       0
# 2       Plabita Borthakur       0       1       0
# 3              Ishita Raj       1       2       0
# 4      Rituparna Sengupta       0       0       0
# 5  Aishwarya Rai Bachchan       1       3       1

# %%
df.to_csv('movies_cleaned.csv', index=False)

# %% [markdown]
# Preparing columns to add in the ML model

# %%
newdf = pd.read_csv('movies_cleaned.csv')

# %%
newdf = pd.DataFrame(newdf)

# %%
newdf.head()
# Out:
#    Year  Duration  Rating  Votes            Director       Actor 1  \
# 0  2019       109     7.0      8       Gaurav Bakshi  Rasika Dugal
# 1  2021        90     6.0     55  Soumyajit Majumdar  Sayani Gupta
# 2  2019       110     4.4     35          Ovais Khan       Prateik
# 3  2010       105     6.0     55        Amol Palekar  Rajat Kapoor
# 4  1997       147     4.7    827        Rahul Rawail    Bobby Deol
#
#                   Actor 2  Genre1  Genre2  Genre3
# 0          Vivek Ghamande       0       0       0
# 1       Plabita Borthakur       0       1       0
# 2              Ishita Raj       1       2       0
# 3      Rituparna Sengupta       0       0       0
# 4  Aishwarya Rai Bachchan       1       3       1

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11086 entries, 0 to 11085
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      11086 non-null  int64
#  1   Duration  11086 non-null  int64
#  2   Rating    11086 non-null  float64
#  3   Votes     11086 non-null  int64
#  4   Director  11086 non-null  object
#  5   Actor 1   11086 non-null  object
#  6   Actor 2   11086 non-null  object
#  7   Genre1    11086 non-null  int64
#  8   Genre2    11086 non-null  int64
#  9   Genre3    11086 non-null  int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 866.2+ KB

# %%
newdf['MovieAge'] = 2024 - newdf['Year']
newdf.head()
# Out:
#    Year  Duration  Rating  Votes            Director       Actor 1  \
# 0  2019       109     7.0      8       Gaurav Bakshi  Rasika Dugal
# 1  2021        90     6.0     55  Soumyajit Majumdar  Sayani Gupta
# 2  2019       110     4.4     35          Ovais Khan       Prateik
# 3  2010       105     6.0     55        Amol Palekar  Rajat Kapoor
# 4  1997       147     4.7    827        Rahul Rawail    Bobby Deol
#
#                   Actor 2  Genre1  Genre2  Genre3  MovieAge
# 0          Vivek Ghamande       0       0       0         5
# 1       Plabita Borthakur       0       1       0         3
# 2              Ishita Raj       1       2       0         5
# 3      Rituparna Sengupta       0       0       0        14
# 4  Aishwarya Rai Bachchan       1       3       1        27

# %%
DirectorCounts = newdf['Director'].value_counts()
newdf['DirectorCount'] = newdf['Director'].map(DirectorCounts)
Actorcounts = newdf['Actor 1'].value_counts()
newdf['Actor1Count'] = newdf['Actor 1'].map(Actorcounts)

# %%
newdf.head()
# Out:
#    Year  Duration  Rating  Votes            Director       Actor 1  \
# 0  2019       109     7.0      8       Gaurav Bakshi  Rasika Dugal
# 1  2021        90     6.0     55  Soumyajit Majumdar  Sayani Gupta
# 2  2019       110     4.4     35          Ovais Khan       Prateik
# 3  2010       105     6.0     55        Amol Palekar  Rajat Kapoor
# 4  1997       147     4.7    827        Rahul Rawail    Bobby Deol
#
#                   Actor 2  Genre1  Genre2  Genre3  MovieAge  DirectorCount  \
# 0          Vivek Ghamande       0       0       0         5              1
# 1       Plabita Borthakur       0       1       0         3              1
# 2              Ishita Raj       1       2       0         5              1
# 3      Rituparna Sengupta       0       0       0        14              7
# 4  Aishwarya Rai Bachchan       1       3       1        27             17
#
#    Actor1Count
# 0            2
# 1            2
# 2            5
# 3            6
# 4           18

# %%
newdf['LoggedVotes'] = np.log(newdf['Votes'])
newdf.head()
# Out:
#    Year  Duration  Rating  Votes            Director       Actor 1  \
# 0  2019       109     7.0      8       Gaurav Bakshi  Rasika Dugal
# 1  2021        90     6.0     55  Soumyajit Majumdar  Sayani Gupta
# 2  2019       110     4.4     35          Ovais Khan       Prateik
# 3  2010       105     6.0     55        Amol Palekar  Rajat Kapoor
# 4  1997       147     4.7    827        Rahul Rawail    Bobby Deol
#
#                   Actor 2  Genre1  Genre2  Genre3  MovieAge  DirectorCount  \
# 0          Vivek Ghamande       0       0       0         5              1
# 1       Plabita Borthakur       0       1       0         3              1
# 2              Ishita Raj       1       2       0         5              1
# 3      Rituparna Sengupta       0       0       0        14              7
# 4  Aishwarya Rai Bachchan       1       3       1        27             17
#
#    Actor1Count  LoggedVotes
# 0            2     2.079442
# 1            2     4.007333
# 2            5     3.555348
# 3            6     4.007333
# 4           18     6.717805

# %%
DirectorRating = newdf.groupby('Director')['Rating'].mean()
newdf['DirectorRating'] = newdf['Director'].map(DirectorRating)

Actor1Rating = newdf.groupby('Actor 1')['Rating'].mean()
newdf['Actor1Rating'] = newdf['Actor 1'].map(Actor1Rating)

Actor2Rating = newdf.groupby('Actor 2')['Rating'].mean()
newdf['Actor2Rating'] = newdf['Actor 2'].map(Actor2Rating)

# %%
newdf.head()
# Out:
#    Year  Duration  Rating  Votes            Director       Actor 1  \
# 0  2019       109     7.0      8       Gaurav Bakshi  Rasika Dugal
# 1  2021        90     6.0     55  Soumyajit Majumdar  Sayani Gupta
# 2  2019       110     4.4     35          Ovais Khan       Prateik
# 3  2010       105     6.0     55        Amol Palekar  Rajat Kapoor
# 4  1997       147     4.7    827        Rahul Rawail    Bobby Deol
#
#                   Actor 2  Genre1  Genre2  Genre3  MovieAge  DirectorCount  \
# 0          Vivek Ghamande       0       0       0         5              1
# 1       Plabita Borthakur       0       1       0         3              1
# 2              Ishita Raj       1       2       0         5              1
# 3      Rituparna Sengupta       0       0       0        14              7
# 4  Aishwarya Rai Bachchan       1       3       1        27             17
#
#    Actor1Count  LoggedVotes  DirectorRating  Actor1Rating  Actor2Rating
# 0            2     2.079442        7.000000      6.850000      7.000000
# 1            2     4.007333        6.000000      6.500000      6.900000
# 2            5     3.555348        4.400000      5.420000      4.400000
# 3            6     4.007333        6.285714      6.833333      5.800000
# 4           18     6.717805        5.358824      4.788889      5.786667

# %%
newdf["Genre1Encoded"] = newdf.groupby('Genre1')['Rating'].transform('mean').round(1)
newdf['Genre2Encoded'] = newdf.groupby('Genre2')['Rating'].transform('mean').round(1)
newdf['Genre3Encoded'] = newdf.groupby('Genre3')['Rating'].transform('mean').round(1)
newdf['VotesEncoded'] = newdf.groupby('Votes')['Rating'].transform('mean').round(1)
newdf['DirectorEncoded'] = newdf.groupby('Director')['Rating'].transform('mean').round(1)
newdf['Actor1Encoded'] = newdf.groupby('Actor 1')['Rating'].transform('mean').round(1)
newdf['Actor2Encoded'] = newdf.groupby('Actor 2')['Rating'].transform('mean').round(1)
newdf.head()
# Out:
#    Year  Duration  Rating  Votes            Director       Actor 1  \
# 0  2019       109     7.0      8       Gaurav Bakshi  Rasika Dugal
# 1  2021        90     6.0     55  Soumyajit Majumdar  Sayani Gupta
# 2  2019       110     4.4     35          Ovais Khan       Prateik
# 3  2010       105     6.0     55        Amol Palekar  Rajat Kapoor
# 4  1997       147     4.7    827        Rahul Rawail    Bobby Deol
#
#                   Actor 2  Genre1  Genre2  Genre3  ...  DirectorRating  \
# 0          Vivek Ghamande       0       0       0  ...        7.000000
# 1       Plabita Borthakur       0       1       0  ...        6.000000
# 2              Ishita Raj       1       2       0  ...        4.400000
# 3      Rituparna Sengupta       0       0       0  ...        6.285714
# 4  Aishwarya Rai Bachchan       1       3       1  ...        5.358824
#
#    Actor1Rating  Actor2Rating  Genre1Encoded  Genre2Encoded  Genre3Encoded  \
# 0      6.850000      7.000000            6.1            5.9            5.9
# 1      6.500000      6.900000            6.1            6.3            5.9
# 2      5.420000      4.400000            5.8            5.8            5.9
# 3      6.833333      5.800000            6.1            5.9            5.9
# 4      4.788889      5.786667            5.8            5.9            6.0
#
#    VotesEncoded  DirectorEncoded  Actor1Encoded  Actor2Encoded
# 0           5.5              7.0            6.8            7.0
# 1           6.0              6.0            6.5            6.9
# 2           5.8              4.4            5.4            4.4
# 3           6.0              6.3            6.8            5.8
# 4           4.8              5.4            4.8            5.8
#
# [5 rows x 24 columns]

# %%
newdf.drop(columns=['Ratring'],inplace=True)

# %%
newdf.columns
# Out:
# Index(['Year', 'Duration', 'Rating', 'Votes', 'Genre1', 'Genre2', 'Genre3',
#        'MovieAge', 'DirectorCount', 'Actor1Count', 'LoggedVotes',
#        'DirectorRating', 'Actor1Rating', 'Actor2Rating', 'Genre1Encoded',
#        'Genre2Encoded', 'Genre3Encoded', 'VotesEncoded', 'DirectorEncoded',
#        'Actor1Encoded', 'Actor2Encoded'],
#       dtype='object')

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11086 entries, 0 to 11085
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             11086 non-null  int64
#  1   Duration         11086 non-null  int64
#  2   Rating           11086 non-null  float64
#  3   Votes            11086 non-null  int64
#  4   Genre1           11086 non-null  int64
#  5   Genre2           11086 non-null  int64
#  6   Genre3           11086 non-null  int64
#  7   MovieAge         11086 non-null  int64
#  8   DirectorCount    11086 non-null  int64
#  9   Actor1Count      11086 non-null  int64
#  10  LoggedVotes      11086 non-null  float64
#  11  DirectorRating   11086 non-null  float64
#  12  Actor1Rating     11086 non-null  float64
#  13  Actor2Rating     11086 non-null  float64
#  14  Genre1Encoded    11086 non-null  float64
#  15  Genre2Encoded    11086 non-null  float64
#  16  Genre3Encoded    11086 non-null  float64
#  17  VotesEncoded     11086 non-null  float64
#  18  DirectorEncoded  11086 non-null  float64
#  19  Actor1Encoded    11086 non-null  float64
#  20  Actor2Encoded    11086 non-null  float64
# dtypes: float64(12), int64(9)
# memory usage: 1.8 MB

# %%
newdf.columns
# Out:
# Index(['Year', 'Duration', 'Rating', 'MovieAge', 'DirectorCount',
#        'Actor1Count', 'LoggedVotes', 'DirectorRating', 'Actor1Rating',
#        'Actor2Rating', 'Genre1Encoded', 'Genre2Encoded', 'Genre3Encoded',
#        'VotesEncoded', 'DirectorEncoded', 'Actor1Encoded', 'Actor2Encoded'],
#       dtype='object')

# %% [markdown]
# Manupalating the Size of Dataframe

# %%
newdf["DirectorEncoded"] = newdf["DirectorEncoded"].astype('int32')
newdf["Actor1Encoded"] = newdf["Actor1Encoded"].astype('int32')
newdf["Actor2Encoded"] = newdf["Actor2Encoded"].astype('int32')
newdf["Genre1Encoded"] = newdf["Genre1Encoded"].astype('int32')
newdf["Genre2Encoded"] = newdf["Genre2Encoded"].astype('int32')
newdf["Genre3Encoded"] = newdf["Genre3Encoded"].astype('int32')
newdf["VotesEncoded"] = newdf["VotesEncoded"].astype('int32')
newdf['Actor1Count'] = newdf['Actor1Count'].astype('int32')
newdf['DirectorCount'] = newdf['DirectorCount'].astype('int32')
newdf['MovieAge'] = newdf['MovieAge'].astype('int32')
newdf['LoggedVotes'] = newdf['LoggedVotes'].astype('int32')

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11086 entries, 0 to 11085
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             11086 non-null  int64
#  1   Duration         11086 non-null  int64
#  2   Rating           11086 non-null  float64
#  3   MovieAge         11086 non-null  int32
#  4   DirectorCount    11086 non-null  int32
#  5   Actor1Count      11086 non-null  int32
#  6   LoggedVotes      11086 non-null  int32
#  7   DirectorRating   11086 non-null  float64
#  8   Actor1Rating     11086 non-null  float64
#  9   Actor2Rating     11086 non-null  float64
#  10  Genre1Encoded    11086 non-null  int32
#  11  Genre2Encoded    11086 non-null  int32
#  12  Genre3Encoded    11086 non-null  int32
#  13  VotesEncoded     11086 non-null  int32
#  14  DirectorEncoded  11086 non-null  int32
#  15  Actor1Encoded    11086 non-null  int32
#  16  Actor2Encoded    11086 non-null  int32
# dtypes: float64(4), int32(11), int64(2)
# memory usage: 996.1 KB

# %% [markdown]
# Using Linear regression for the ML model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# 70% Train 30% test split

# %%
X=newdf.drop("Rating",axis=1)
Y=newdf["Rating"]

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=52)

model=LinearRegression()
model.fit(X_train,Y_train)

X_test_prediction= model.predict(X_test)

mse =mean_squared_error(Y_test,X_test_prediction)
print(f"Mean Squared Error (MSE): {mse:.2f}")

r2 = r2_score(Y_test,X_test_prediction)
print(f"R-squared score: {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 0.33
# R-squared score: 0.74

# %% [markdown]
# Checking Accuracy of Model
